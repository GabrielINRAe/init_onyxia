# %%
import xarray as xr
import numpy as np
import rioxarray as rio
import holoviews as hv
import hvplot.xarray
hv.extension("bokeh")
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='8f702777-def3-4cac-bf1d-92c9fae0d433'>
#   <div id="a9173131-a5ae-4201-b243-43505ed4645b" data-root-id="8f702777-def3-4cac-bf1d-92c9fae0d433" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
mndwi = xr.open_dataarray("/home/onyxia/work/prod/mndwi_2020.nc").chunk("auto")
mndwi = mndwi.astype(np.float16)

# %%
mndwi
# Out:
# <xarray.DataArray 'mndwi_2020' (y: 6250, x: 5667, time: 13)> Size: 921MB
# dask.array<astype, shape=(6250, 5667, 13), dtype=float16, chunksize=(1606, 1606, 13), chunktype=numpy.ndarray>
# Coordinates:
#   * y            (y) float64 50kB 6.651e+06 6.651e+06 ... 6.589e+06 6.589e+06
#   * x            (x) float64 45kB 5.376e+05 5.376e+05 ... 5.942e+05 5.942e+05
#   * time         (time) datetime64[ns] 104B 2020-01-15 2020-02-15 ... 2020-12-15
#     spatial_ref  int32 4B ...

# %%
reduce = xr.open_dataarray("/home/onyxia/work/data/masque_etangs_reduit.tif")
mndwi_light = xr.align(reduce,mndwi,join="left")[1].compute()
mndwi_light
# Out:
# <xarray.DataArray 'mndwi_2020' (y: 623, x: 790, time: 13)> Size: 13MB
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
# ...

# %%
median = mndwi_light.median(dim="time",skipna=True)
